# %% [markdown]
# # 2020-수학-가형-홀수-16

# %% [markdown]
# ## 문제
# ![2020-수학-가형-홀수-16](https://wiki.mathnt.net/img_auth.php/0/05/0d96f32eacdd85919fc30bed9bc36751e8b49d8c.png)

# %% [markdown]
# ## 풀이

# %%
result = []
for a in range(14):
    for b in range(14):
        for c in range(14):
            for d in range(5):
                if a+b+c-d ==9 and c>=d :
                    print([a,b,c,d])
                    result.append([a,b,c,d])
# Out:
# [0, 0, 9, 0]
# [0, 0, 10, 1]
# [0, 0, 11, 2]
# [0, 0, 12, 3]
# [0, 0, 13, 4]
# [0, 1, 8, 0]
# [0, 1, 9, 1]
# [0, 1, 10, 2]
# [0, 1, 11, 3]
# [0, 1, 12, 4]
# [0, 2, 7, 0]
# [0, 2, 8, 1]
# [0, 2, 9, 2]
# [0, 2, 10, 3]
# [0, 2, 11, 4]
# [0, 3, 6, 0]
# [0, 3, 7, 1]
# [0, 3, 8, 2]
# [0, 3, 9, 3]
# [0, 3, 10, 4]
# [0, 4, 5, 0]
# [0, 4, 6, 1]
# [0, 4, 7, 2]
# [0, 4, 8, 3]
# [0, 4, 9, 4]
# [0, 5, 4, 0]
# [0, 5, 5, 1]
# [0, 5, 6, 2]
# [0, 5, 7, 3]
# [0, 5, 8, 4]
# [0, 6, 3, 0]
# [0, 6, 4, 1]
# [0, 6, 5, 2]
# [0, 6, 6, 3]
# [0, 6, 7, 4]
# [0, 7, 2, 0]
# [0, 7, 3, 1]
# [0, 7, 4, 2]
# [0, 7, 5, 3]
# [0, 7, 6, 4]
# [0, 8, 1, 0]
# [0, 8, 2, 1]
# [0, 8, 3, 2]
# [0, 8, 4, 3]
# [0, 8, 5, 4]
# [0, 9, 0, 0]
# [0, 9, 1, 1]
# [0, 9, 2, 2]
# [0, 9, 3, 3]
# [0, 9, 4, 4]
# [1, 0, 8, 0]
# [1, 0, 9, 1]
# [1, 0, 10, 2]
# [1, 0, 11, 3]
# [1, 0, 12, 4]
# [1, 1, 7, 0]
# [1, 1, 8, 1]
# [1, 1, 9, 2]
# [1, 1, 10, 3]
# [1, 1, 11, 4]
# [1, 2, 6, 0]
# [1, 2, 7, 1]
# [1, 2, 8, 2]
# [1, 2, 9, 3]
# [1, 2, 10, 4]
# ...

# %%
len(result)
# Out:
# 275
